# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer


import numpy as np

import tensorflow as tf

# %%
### analisis breve de los datos contenidos en la base de datos ### 

url = 'https://raw.githubusercontent.com/Mauascm/Model_PayEmUP/main/Salary2USA.csv'
data = pd.read_csv(url)

#### tomando solamente una muestra de los datos para tener una prueba rápida.
data = data.sample(frac=0.25, random_state=42)

# Ver las primeras filas de los datos
print(data.head())

# Ver información general sobre los datos
print(data.info())

# Ver estadísticas descriptivas de las variables numéricas
print(data.describe())

# Ver la cantidad de valores únicos en cada columna
print(data.nunique())


### ---------------------------- ###
# Out:
#                CASE_NUMBER          CASE_STATUS CASE_RECEIVED_DATE
# 34190   I-200-13267-221220            certified          9/24/2013  \
# 137917  I-200-13039-257242            certified           2/8/2013
# 65281   I-200-13262-493824            certified         10/29/2013
# 27111        A-14162-77222    certified-expired          8/11/2014
# 137879  I-200-14190-296562  certified-withdrawn           7/9/2014
#
#        DECISION_DATE            EMPLOYER_NAME  PREVAILING_WAGE_SUBMITTED
# 34190     10/23/2013     JPMORGAN CHASE & CO.                    94890.0  \
# 137917     2/14/2013      IGT SOLUTIONS, INC.                    50960.0
# 65281      11/7/2013           EMC CORPORTION                    77937.0
# 27111     12/30/2014      CISCO SYSTEMS, INC.                    98927.0
# 137879     1/12/2015  OREGON STATE UNIVERSITY                    51000.0
#
#        PREVAILING_WAGE_SUBMITTED_UNIT  PAID_WAGE_SUBMITTED
# 34190                            year             115000.0  \
# 137917                           year              62000.0
# 65281                            year              95000.0
# 27111                            year              98927.0
# 137879                           year             100008.0
#
#        PAID_WAGE_SUBMITTED_UNIT                 JOB_TITLE  ...
# 34190                      year          BUSINESS ANALYST  ...  \
# 137917                     year          BUSINESS ANALYST  ...
# 65281                      year  SENIOR SOFTWARE ENGINEER  ...
# 27111                      year         Software Engineer  ...
# 137879                     year       ASSISTANT PROFESSOR  ...
#
#        PREVAILING_WAGE_SOC_CODE                 PREVAILING_WAGE_SOC_TITLE
# 34190                   15-1121                 Computer Systems Analysts  \
# 137917                  15-1121                 Computer Systems Analysts
# 65281                   15-1132         Software Developers, Applications
# 27111                   15-1133     Software Developers, Systems Software
# 137879                  25-1021  COMPUTER SCIENCE TEACHERS, POSTSECONDARY
#
#         WORK_STATE WORK_POSTAL_CODE  FULL_TIME_POSITION_Y_N VISA_CLASS
# 34190           NY              NaN                       y       H-1B  \
# 137917          TX              NaN                       y       H-1B
# 65281           MA              NaN                       y       H-1B
# 27111   CALIFORNIA          95134.0                     NaN  greencard
# 137879          OR            97331                       y       H-1B
#
#        PREVAILING_WAGE_PER_YEAR PAID_WAGE_PER_YEAR   JOB_TITLE_SUBGROUP
# 34190                   94890.0           115000.0     business analyst  \
# 137917                  50960.0            62000.0     business analyst
# 65281                   77937.0            95000.0    software engineer
# 27111                   98927.0            98927.0    software engineer
# 137879                  51000.0           100008.0  assistant professor
#
#          order
# 34190    34256
# 137917  138001
# 65281    65364
# 27111    27173
# 137879  137963
#
# [5 rows x 26 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 41820 entries, 34190 to 34834
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CASE_NUMBER                     41820 non-null  object
#  1   CASE_STATUS                     41820 non-null  object
#  2   CASE_RECEIVED_DATE              41820 non-null  object
#  3   DECISION_DATE                   41820 non-null  object
#  4   EMPLOYER_NAME                   41820 non-null  object
#  5   PREVAILING_WAGE_SUBMITTED       41820 non-null  float64
#  6   PREVAILING_WAGE_SUBMITTED_UNIT  41820 non-null  object
#  7   PAID_WAGE_SUBMITTED             41820 non-null  float64
#  8   PAID_WAGE_SUBMITTED_UNIT        41820 non-null  object
#  9   JOB_TITLE                       41820 non-null  object
#  10  WORK_CITY                       41819 non-null  object
#  11  EDUCATION_LEVEL_REQUIRED        2778 non-null   object
#  12  COLLEGE_MAJOR_REQUIRED          2774 non-null   object
#  13  EXPERIENCE_REQUIRED_Y_N         2786 non-null   object
#  14  EXPERIENCE_REQUIRED_NUM_MONTHS  1240 non-null   float64
#  15  COUNTRY_OF_CITIZENSHIP          2786 non-null   object
#  16  PREVAILING_WAGE_SOC_CODE        41820 non-null  object
#  17  PREVAILING_WAGE_SOC_TITLE       41820 non-null  object
#  18  WORK_STATE                      41820 non-null  object
#  19  WORK_POSTAL_CODE                13424 non-null  object
#  20  FULL_TIME_POSITION_Y_N          39034 non-null  object
#  21  VISA_CLASS                      41820 non-null  object
#  22  PREVAILING_WAGE_PER_YEAR        41805 non-null  float64
#  23  PAID_WAGE_PER_YEAR              41820 non-null  float64
#  24  JOB_TITLE_SUBGROUP              41820 non-null  object
#  25  order                           41820 non-null  int64
# dtypes: float64(5), int64(1), object(20)
# memory usage: 8.6+ MB
# None
#        PREVAILING_WAGE_SUBMITTED  PAID_WAGE_SUBMITTED
# count               4.182000e+04         4.182000e+04  \
# mean                7.096854e+04         8.141661e+04
# std                 4.331239e+04         3.921110e+04
# min                 5.050000e+00         5.100000e+00
# 25%                 5.428800e+04         6.100000e+04
# 50%                 6.957600e+04         7.687600e+04
# 75%                 8.966900e+04         1.000000e+05
# max                 6.217100e+06         1.000906e+06
#
#        EXPERIENCE_REQUIRED_NUM_MONTHS  PREVAILING_WAGE_PER_YEAR
# count                     1240.000000              41805.000000  \
# mean                        33.737097              74071.623099
# std                         22.421962              25277.971045
# min                          0.000000              10504.000000
# 25%                         12.000000              56680.000000
# 50%                         24.000000              70600.000000
# 75%                         60.000000              90313.600000
# max                        144.000000             244233.600000
#
#        PAID_WAGE_PER_YEAR          order
# count        4.182000e+04   41820.000000
# mean         8.531314e+04   84155.535318
# std          3.618746e+04   48211.379097
# min          1.060800e+04       1.000000
# 25%          6.271200e+04   42339.750000
# 50%          7.800000e+04   84233.500000
# 75%          1.000000e+05  126000.250000
# max          1.176000e+06  167360.000000
# CASE_NUMBER                       41820
# CASE_STATUS                           5
# CASE_RECEIVED_DATE                 1455
# DECISION_DATE                       803
# EMPLOYER_NAME                     11382
# PREVAILING_WAGE_SUBMITTED          8932
# PREVAILING_WAGE_SUBMITTED_UNIT        5
# PAID_WAGE_SUBMITTED                8909
# PAID_WAGE_SUBMITTED_UNIT              5
# JOB_TITLE                          4774
# WORK_CITY                          2943
# EDUCATION_LEVEL_REQUIRED              6
# COLLEGE_MAJOR_REQUIRED             1079
# EXPERIENCE_REQUIRED_Y_N               2
# EXPERIENCE_REQUIRED_NUM_MONTHS       19
# COUNTRY_OF_CITIZENSHIP               94
# PREVAILING_WAGE_SOC_CODE            305
# PREVAILING_WAGE_SOC_TITLE           406
# WORK_STATE                          107
# WORK_POSTAL_CODE                   3312
# FULL_TIME_POSITION_Y_N                2
# VISA_CLASS                            5
# PREVAILING_WAGE_PER_YEAR           8671
# PAID_WAGE_PER_YEAR                 8716
# JOB_TITLE_SUBGROUP                    8
# order                             41820
# dtype: int64

# %%
# Definir las columnas socio-demográficas y académicas
socio_demographic_cols = ['CASE_STATUS', 'EMPLOYER_NAME', 'PREVAILING_WAGE_SUBMITTED', 'PREVAILING_WAGE_SUBMITTED_UNIT', 'WORK_CITY', 'COUNTRY_OF_CITIZENSHIP', 'WORK_STATE', 'WORK_POSTAL_CODE', 'FULL_TIME_POSITION_Y_N', 'VISA_CLASS']
academic_cols = ['EDUCATION_LEVEL_REQUIRED', 'COLLEGE_MAJOR_REQUIRED', 'EXPERIENCE_REQUIRED_Y_N', 'EXPERIENCE_REQUIRED_NUM_MONTHS', 'PREVAILING_WAGE_SOC_CODE', 'PREVAILING_WAGE_SOC_TITLE', 'JOB_TITLE_SUBGROUP']

# Crear los transformadores para las columnas numéricas y categóricas
num_transformer = StandardScaler()
cat_transformer = OneHotEncoder(drop='first')

# Crear un preprocesador que aplique las transformaciones a las columnas correspondientes
preprocessor_socio_demographic = ColumnTransformer(
    transformers=[
        ('num', num_transformer, ['PREVAILING_WAGE_SUBMITTED']),
        ('cat', cat_transformer, socio_demographic_cols)])

preprocessor_academic = ColumnTransformer(
    transformers=[
        ('num', num_transformer, ['EXPERIENCE_REQUIRED_NUM_MONTHS']),
        ('cat', cat_transformer, academic_cols)])

# Crear un pipeline que aplique el preprocesador y luego ajuste el modelo
pipeline_socio_demographic = Pipeline(steps=[('preprocessor', preprocessor_socio_demographic)])
pipeline_academic = Pipeline(steps=[('preprocessor', preprocessor_academic)])

# Aplicar las transformaciones a los datos
data_preprocessed_socio_demographic = pipeline_socio_demographic.fit_transform(data[socio_demographic_cols])
data_preprocessed_academic = pipeline_academic.fit_transform(data[academic_cols])

# La variable objetivo es el salario pagado
salary = data['PAID_WAGE_PER_YEAR']

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train_socio_demographic, X_test_socio_demographic, y_train_socio_demographic, y_test_socio_demographic = train_test_split(data_preprocessed_socio_demographic, salary, test_size=0.2, random_state=42)
X_train_academic, X_test_academic, y_train_academic, y_test_academic = train_test_split(data_preprocessed_academic, salary, test_size=0.2, random_state=42)

print('Datos preprocesados y divididos en conjuntos de entrenamiento y prueba.')
# Out:
# Datos preprocesados y divididos en conjuntos de entrenamiento y prueba.

# %%
# Crear un imputador que rellena los valores faltantes con la media
imputer = SimpleImputer(strategy='mean')

# Aplicar el imputador a los datos de entrenamiento
X_train_socio_demographic_imputed = imputer.fit_transform(X_train_socio_demographic)
X_train_academic_imputed = imputer.fit_transform(X_train_academic)

# Crear los modelos
model_socio_demographic = LinearRegression()
model_academic = LinearRegression()

# Entrenar los modelos
model_socio_demographic.fit(X_train_socio_demographic_imputed, y_train_socio_demographic)
model_academic.fit(X_train_academic_imputed, y_train_academic)

# Evaluar los modelos
train_score_socio_demographic = model_socio_demographic.score(X_train_socio_demographic_imputed, y_train_socio_demographic)
test_score_socio_demographic = model_socio_demographic.score(X_test_socio_demographic, y_test_socio_demographic)

train_score_academic = model_academic.score(X_train_academic_imputed, y_train_academic)
test_score_academic = model_academic.score(X_test_academic, y_test_academic)

print(f'Exactitud del modelo socio-demográfico en el conjunto de entrenamiento: {train_score_socio_demographic:.2f}')
print(f'Exactitud del modelo socio-demográfico en el conjunto de prueba: {test_score_socio_demographic:.2f}')

print(f'Exactitud del modelo académico en el conjunto de entrenamiento: {train_score_academic:.2f}')
print(f'Exactitud del modelo académico en el conjunto de prueba: {test_score_academic:.2f}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 21
#      18 test_score_socio_demographic = model_socio_demographic.score(X_test_socio_demographic, y_test_socio_demographic)
#      20 train_score_academic = model_academic.score(X_train_academic_imputed, y_train_academic)
# ---> 21 test_score_academic = model_academic.score(X_test_academic, y_test_academic)
#      23 print(f'Exactitud del modelo socio-demográfico en el conjunto de entrenamiento: {train_score_socio_demographic:.2f}')
#      24 print(f'Exactitud del modelo socio-demográfico en el conjunto de prueba: {test_score_socio_demographic:.2f}')
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:722, in RegressorMixin.score(self, X, y, sample_weight)
#     680 """Return the coefficient of determination of the prediction.
#     681
#     682 The coefficient of determination :math:`R^2` is defined as
#    (...)
#     717 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     718 """
#     720 from .metrics import r2_score
# --> 722 y_pred = self.predict(X)
#     723 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_base.py:354, in LinearModel.predict(self, X)
#     340 def predict(self, X):
#     341     """
#     342     Predict using the linear model.
#     343
#    (...)
#     352         Returns predicted values.
#     353     """
# --> 354     return self._decision_function(X)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_base.py:337, in LinearModel._decision_function(self, X)
#     334 def _decision_function(self, X):
#     335     check_is_fitted(self)
# --> 337     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     338     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:565, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     563     raise ValueError("Validation should be done on X, y or both.")
#     564 elif not no_val_X and no_val_y:
# --> 565     X = check_array(X, input_name="X", **check_params)
#     566     out = X
#     567 elif no_val_X and not no_val_y:
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:845, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     843 if sp.issparse(array):
#     844     _ensure_no_complex_data(array)
# --> 845     array = _ensure_sparse_format(
#     846         array,
#     847         accept_sparse=accept_sparse,
#     848         dtype=dtype,
#     849         copy=copy,
#     850         force_all_finite=force_all_finite,
#     851         accept_large_sparse=accept_large_sparse,
#     852         estimator_name=estimator_name,
#     853         input_name=input_name,
#     854     )
#     855 else:
#     856     # If np.array(..) gives ComplexWarning, then we convert the warning
#     857     # to an error. This is needed because specifying a non complex
#     858     # dtype to the function converts complex to real dtype,
#     859     # thereby passing the test made in the lines following the scope
#     860     # of warnings context manager.
#     861     with warnings.catch_warnings():
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:561, in _ensure_sparse_format(spmatrix, accept_sparse, dtype, copy, force_all_finite, accept_large_sparse, estimator_name, input_name)
#     556         warnings.warn(
#     557             "Can't check %s sparse matrix for nan or inf." % spmatrix.format,
#     558             stacklevel=2,
#     559         )
#     560     else:
# --> 561         _assert_all_finite(
#     562             spmatrix.data,
#     563             allow_nan=force_all_finite == "allow-nan",
#     564             estimator_name=estimator_name,
#     565             input_name=input_name,
#     566         )
#     568 return spmatrix
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:161, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144 if estimator_name and input_name == "X" and has_nan_error:
#     145     # Improve the error message on how to handle missing values in
#     146     # scikit-learn.
#     147     msg_err += (
#     148         f"\n{estimator_name} does not accept missing values"
#     149         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     159         "#estimators-that-handle-nan-values"
#     160     )
# --> 161 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# LinearRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
